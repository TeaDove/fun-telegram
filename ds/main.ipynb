# %%
import pandas as pd

# %%
df = pd.read_parquet("../core/service/analitics/.test-channels.pqt")
df
# Out:
#             tg_id                                      tg_title  \
# 0      1000029537                               Пыльный Саратов
# 1      1000058135                                      Republic
# 2      1000087183                 رئال مادرید | Real Madrid C.F
# 3      1000150092                    Conflict Intelligence Team
# 4      1000154882                               Books & Reviews
# ...           ...                                           ...
# 32885  2146050510                            пикантный гороскоп
# 32886  2146488626                                    Зимавсегда
# 32887  2146498218                                     Иви-киви🥝
# 32888  2146823414                                    лилечка x2
# 32889  2146958420  ✨яркие объёмные ногти | Новокузнецк | Вика🍓✨
#
#             tg_username  participant_count  is_leaf  \
# 0           saratovlive               1655    False
# 1           RepublicMag              16710    False
# ...

# %%
df = pd.read_parquet("../core/service/analitics/.test-channels_edges.pqt")
df
# Out:
#           tg_about   tg_id_out  order
# 0       1000150092  1001497499      7
# 1       1000150092  1003921752      5
# 2       1000150092  1004504016     80
# 3       1000150092  1005031786     49
# 4       1000150092  1005993407     53
# ...            ...         ...    ...
# 180808  2145686167  2123458574     11
# 180809  2145686167  2140138790     15
# 180810  2145686167  2141370560     33
# 180811  2145686167  2144579813      3
# 180812  2145686167  2144846578      0
#
# [180813 rows x 3 columns]

# %%
df = pd.read_parquet("../core/service/analitics/.test-messages.pqt")
df
# Out:
#                 created_at  tg_chat_id   tg_id  tg_user_id  \
# 0      2018-04-29 14:03:45  1364081847       2  1364081847
# 1      2018-04-30 00:27:19  1364081847       4  1364081847
# 2      2018-04-30 11:29:33  1364081847       5  1364081847
# 3      2018-04-30 12:36:03  1364081847       6  1364081847
# 4      2018-04-30 17:10:47  1364081847       7  1364081847
# ...                    ...         ...     ...         ...
# 293382 2024-03-12 19:20:30  1837498119  330487  1837498119
# 293383 2024-03-12 19:20:42  1955127321   16336  1955127321
# 293384 2024-03-12 19:20:42  1955127321   16336  1955127321
# 293385 2024-03-12 19:21:54  1766926018   12441  1766926018
# 293386 2024-03-12 19:21:54  1766926018   12441  1766926018
#
#                                                      text  words_count  \
# 0       Завтра (30 апреля) в 14:00 в Москве на проспек...           69
# 1                            https://youtu.be/FT6TVvAQ5OY            1
# ...

# %%
import pandas as pd

# %%
df = pd.read_parquet("../core/service/analitics/channels.pqt")
df
# Out:
#            tg_id                                   tg_title  \
# 0     1000150092                 Conflict Intelligence Team
# 1     1000724666                              Naked Science
# 2     1001497499                                The Insider
# 3     1002209029                             Disgusting Men
# 4     1002320701  «Войс» | Voice | Не бывший «Космополитан»
# ...          ...                                        ...
# 3173  2137101577                      I’m real vamp V2🧛‍♂️🩸
# 3174  2138844307                         𝐒𝐡𝐩𝐫𝐨𝐭𝐨𝐯 & 𝐑𝐢𝐳𝐨𝐦𝐨𝐯
# 3175  2140180426                            Лев Зулькарнаев
# 3176  2140657533                          Екатерина Дунцова
# 3177  2141998329                           Никита Литвинков
#
#                tg_username  participant_count  is_leaf  \
# 0                   CITeam             125115    False
# 1                    nsmag             187350    False
# 2               theinsider             121533    False
# 3            disgustingmen              18111    False
# 4               voicemedia               5924     True
# ...                    ...                ...      ...
# 3173              vamp_new               8905    False
# 3174       ShprotovRizomov               1688    False
# 3175                zullev             306286    False
# 3176              Duntsova             264926    False
# 3177  NIKITA_LITVINKOV_ART               1710     True
#
#                                                tg_about
# 0     Записаться в волонтёры CIT: пишите в бот обрат...
# 1                                                  None
# 2     Расследования. Новости. Аналитика.\nhttp://the...
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 3173                                               None
# 3174  Приключения журналистов Ильи Шепелина и Андрея...
# 3175  Открытые дневники\n\nреклама: lev_zul@nextupme...
# 3176  Кандидат в президенты, за мирную демократическ...
# 3177                                               None
#
# [3178 rows x 6 columns]

# %%
df = pd.read_parquet("../core/service/analitics/channels_edges.pqt")
df
# Out:
#          tg_id_in   tg_id_out  order
# 0      1480306544  1881556956      7
# 1      1398964396  1702665787      4
# 2      1060302681  1252424167      7
# 3      1607140386  1394050290      6
# 4      1271173460  1340794803      6
# ...           ...         ...    ...
# 15699  1003698528  1100158992      6
# 15700  1436944945  1255428755      0
# 15701  1012103617  1260622817      3
# 15702  1404369310  1745015089      5
# 15703  1980097656  1206146772      8
#
# [15704 rows x 3 columns]

# %%
df = pd.read_parquet("../core/service/analitics/messages.pqt")
df
# Out:
#                 created_at  tg_chat_id  tg_id  tg_user_id  \
# 0      2024-02-09 16:21:07  1000150092   3986  1000150092
# 1      2024-02-09 19:36:32  1000150092   3987  1000150092
# 2      2024-02-09 19:54:59  1000150092   3988  1000150092
# 3      2024-02-11 16:36:40  1000150092   3989  1000150092
# 4      2024-02-11 16:37:05  1000150092   3991  1000150092
# ...                    ...         ...    ...         ...
# 146478 2024-03-10 13:10:22  2140657533    228  2140657533
# 146479 2024-03-10 19:34:06  2140657533    230  2140657533
# 146480 2024-03-11 16:58:49  2140657533    232  2140657533
# 146481 2024-03-12 08:11:57  2140657533    233  2140657533
# 146482 2024-03-12 15:09:12  2140657533    234  2140657533
#
#                                                      text  words_count  \
# 0       Текстовая версия сводки: https://notes.citeam....            4
# 1       Всего за прошедшие сутки (20:00 08.02.2024 - 2...          120
# 2       Волонтёрская сводка по мобилизации в РФ за 8–9...           35
# 3       Российские военные в очередной раз совершили т...           97
# 4       Согласно Женевским конвенциям 1949 года, ни од...          201
# ...                                                   ...          ...
# 146478  День рождения отмечает «Ковчег»: важный проект...           80
# 146479  ❗️ Мы закончили рассылку активистам\n\nМы заве...           54
# 146480  ❗️СЕГОДНЯ, 11 марта, в 23:59 заканчивается при...           74
# 146481  🌞 Наступил «Рассвет»! Сегодня мы официально за...           28
# 146482  ❗️Друзья, мы с командой записали серию политич...           64
#
#         toxic_words_count  reply_to_msg_id  reply_to_user_id
# 0                       0           3985.0               NaN
# 1                       1              NaN               NaN
# 2                       1              NaN               NaN
# 3                       2              NaN               NaN
# 4                       2           3989.0               NaN
# ...                   ...              ...               ...
# 146478                  0              NaN               NaN
# 146479                  0              NaN               NaN
# 146480                  4              NaN               NaN
# 146481                  0              NaN               NaN
# 146482                  3              NaN               NaN
#
# [146483 rows x 9 columns]

# %%
import matplotlib.pyplot as plt
from netgraph import Graph

# Several graph formats are supported:

# # 1) edge lists
# graph_data = [(0, 1), (1, 2), (2, 0)]

# # 2) edge list with weights
# graph_data = [(0, 1, 0.2), (1, 2, -0.4), (2, 0, 0.7)]

# 3) full rank matrices
import numpy as np

graph_data = np.random.rand(10, 10)


# Create a non-interactive plot:
Graph(graph_data, node_layout="radial")
plt.show()

# # Create an interactive plot, in which the nodes can be re-positioned with the mouse.
# # NOTE: you must retain a reference to the plot instance!
# # Otherwise, the plot instance will be garbage collected after the initial draw
# # and you won't be able to move the plot elements around.
# # For related reasons, if you are using PyCharm, you have to execute the code in
# # a console (Alt+Shift+E).
# plot_instance = InteractiveGraph(graph_data)
# plt.show()

# # Create an editable plot, which is an interactive plot with the additions
# # that nodes and edges can be inserted or deleted, and labels and annotations
# # can be created, edited, or deleted as well.
# plot_instance = EditableGraph(graph_data)
# plt.show()

# # Netgraph uses Matplotlib for creating the visualisation.
# # Node and edge artistis are derived from `matplotlib.patches.PathPatch`.
# # Node and edge labels are `matplotlib.text.Text` instances.
# # Standard matplotlib syntax applies.
fig, ax = plt.subplots(figsize=(5, 4))
plot_instance = Graph([(0, 1)], node_labels=True, edge_labels=True, ax=ax)
plot_instance.node_artists[0].set_alpha(0.2)
plot_instance.edge_artists[(0, 1)].set_facecolor("red")
plot_instance.edge_label_artists[(0, 1)].set_style("italic")
plot_instance.node_label_artists[1].set_size(10)
ax.set_title("This is my fancy title.")
ax.set_facecolor("honeydew")  # change background color
fig.canvas.draw()  # force redraw to display changes
fig.savefig("test.pdf", dpi=300)
plt.show()

# # Read the documentation for a full list of available arguments:
# help(Graph)
# help(InteractiveGraph)
# help(EditableGraph)
